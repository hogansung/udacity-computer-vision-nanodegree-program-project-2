# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:**
# - Trial A: Follow the paper [Show and Tell: A Neural Image Caption Generator](https://arxiv.org/pdf/1411.4555.pdf).
# - Trial B: Follow the paper [Show, Attend and Tell: Neural Image Caption
# Generation with Visual Attention](https://arxiv.org/pdf/1502.03044.pdf).
#
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:**
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:**
# Given that ResNet is a pretrained image neural network, one can simply remove the last layer, add an additional full-connected layer, and only train the additonal layer. The reason why this would work is because full-connected layer itself always has the capacity to **transfer** what is captured in pretrained layers to the new task.
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:**

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader_wrapper import DataLoaderWrapper
from model import EncoderCNN, DecoderRNN
import math


## TODO #1: Select appropriate values for the Python variables below.
batch_size = 16
vocab_threshold = 5
vocab_from_file = True
embed_size = 64  # 512
hidden_size = 64  # 512
num_epochs = 3  # number of training epochs
save_every = 1  # determines frequency of saving model weights
print_every = 100  # determines window for printing average loss
log_file = "training_log.txt"  # name of file with saved training loss and perplexity

transform_train = transforms.Compose(
    [
        transforms.Resize(256),  # smaller edge of image resized to 256
        transforms.RandomCrop(224),  # get 224x224 crop from random location
        transforms.RandomHorizontalFlip(),  # horizontally flip image with probability=0.5
        transforms.ToTensor(),  # convert the PIL Image to a tensor
        transforms.Normalize(
            (0.485, 0.456, 0.406),  # normalize image for pre-trained model
            (0.229, 0.224, 0.225),
        ),
    ]
)

# Build data loader.
data_loader_wrapper = DataLoaderWrapper(
    transform=transform_train,
    batch_size_for_training=batch_size,
    vocab_threshold=vocab_threshold,
    vocab_from_file=vocab_from_file,
)

# The size of the vocabulary.
vocab_size = len(data_loader_wrapper.dataset_for_training.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(encoder.embed.parameters()) + list(decoder.parameters())

# TODO #4: Define the optimizer.
optimizer = torch.optim.Adam(params, lr=0.0001)

# Set the total number of training steps per epoch.
total_step = math.ceil(
    len(data_loader_wrapper.dataset_for_training.caption_lengths)
    / data_loader_wrapper.dataset_for_training.batch_size
)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# Preparing data
# loading annotations into memory...
# Done (t=0.40s)
# creating index...
# index created!
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:06<00:00, 164.69it/s]
# Vocabulary successfully loaded from vocab.pkl file!

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
response = requests.request(
    "GET",
    "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token",
    headers={"Metadata-Flavor": "Google"},
)

for epoch in range(1, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        
        if time.time() - old_time > 60:
            old_time = time.time()
            requests.request(
                "POST",
                "https://nebula.udacity.com/api/v1/remote/keep-alive",
                headers={"Authorization": "STAR " + response.text},
            )
        
        # Obtain the batch.
        images, captions = next(
            iter(data_loader_wrapper.get_data_loader_for_training())
        )

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = "Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f" % (
            epoch,
            num_epochs,
            i_step,
            total_step,
            loss.item(),
            np.exp(loss.item()),
        )
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# Sampled caption length: 12
# Epoch [1/3], Step [1/63], Loss: 1.1327, Perplexity: 3.1039
# Sampled caption length: 11
# Epoch [1/3], Step [2/63], Loss: 1.1228, Perplexity: 3.0735
# Sampled caption length: 11
# Epoch [1/3], Step [3/63], Loss: 1.1159, Perplexity: 3.0522
# Sampled caption length: 13
# Epoch [1/3], Step [4/63], Loss: 1.1010, Perplexity: 3.0072
# Sampled caption length: 13
# Epoch [1/3], Step [5/63], Loss: 1.0767, Perplexity: 2.9351
# Sampled caption length: 12
# Epoch [1/3], Step [6/63], Loss: 1.0832, Perplexity: 2.9540
# Sampled caption length: 14
# Epoch [1/3], Step [7/63], Loss: 1.0605, Perplexity: 2.8877
# Sampled caption length: 11
# Epoch [1/3], Step [8/63], Loss: 1.0503, Perplexity: 2.8585
# Sampled caption length: 13
# Epoch [1/3], Step [9/63], Loss: 1.0396, Perplexity: 2.8280
# Sampled caption length: 15
# Epoch [1/3], Step [10/63], Loss: 1.0409, Perplexity: 2.8318
# Sampled caption length: 13
# Epoch [1/3], Step [11/63], Loss: 1.0346, Perplexity: 2.8140
# Sampled caption length: 16
# Epoch [1/3], Step [12/63], Loss: 1.0204, Perplexity: 2.7744
# Sampled caption length: 12
# Epoch [1/3], Step [13/63], Loss: 1.0045, Perplexity: 2.7304
# Sampled caption length: 15
# Epoch [1/3], Step [14/63], Loss: 1.0000, Perplexity: 2.7184
# Sampled caption length: 16
# Epoch [1/3], Step [15/63], Loss: 0.9857, Perplexity: 2.6798
# Sampled caption length: 16
# Epoch [1/3], Step [16/63], Loss: 0.9843, Perplexity: 2.6759
# Sampled caption length: 15
# Epoch [1/3], Step [17/63], Loss: 0.9811, Perplexity: 2.6674
# Sampled caption length: 14
# Epoch [1/3], Step [18/63], Loss: 0.9668, Perplexity: 2.6295
# Sampled caption length: 11
# Epoch [1/3], Step [19/63], Loss: 0.9581, Perplexity: 2.6068
# Sampled caption length: 14
# Epoch [1/3], Step [20/63], Loss: 0.9567, Perplexity: 2.6031
# Sampled caption length: 11
# Epoch [1/3], Step [21/63], Loss: 0.9478, Perplexity: 2.5800
# Sampled caption length: 17
# Epoch [1/3], Step [22/63], Loss: 0.9325, Perplexity: 2.5408
# Sampled caption length: 10
# Epoch [1/3], Step [23/63], Loss: 0.9371, Perplexity: 2.5526
# Sampled caption length: 11
# Epoch [1/3], Step [24/63], Loss: 0.9252, Perplexity: 2.5225
# Sampled caption length: 12
# Epoch [1/3], Step [25/63], Loss: 0.9145, Perplexity: 2.4956
# Sampled caption length: 10
# Epoch [1/3], Step [26/63], Loss: 0.9188, Perplexity: 2.5062
# Sampled caption length: 12
# Epoch [1/3], Step [27/63], Loss: 0.9013, Perplexity: 2.4627
# Sampled caption length: 15
# Epoch [1/3], Step [28/63], Loss: 0.8849, Perplexity: 2.4226
# Sampled caption length: 12
# Epoch [1/3], Step [29/63], Loss: 0.8886, Perplexity: 2.4317
# Sampled caption length: 14
# Epoch [1/3], Step [30/63], Loss: 0.8765, Perplexity: 2.4025
# Sampled caption length: 12
# Epoch [1/3], Step [31/63], Loss: 0.8732, Perplexity: 2.3947
# Sampled caption length: 12
# Epoch [1/3], Step [32/63], Loss: 0.8688, Perplexity: 2.3840
# Sampled caption length: 16
# Epoch [1/3], Step [33/63], Loss: 0.8510, Perplexity: 2.3420
# Sampled caption length: 11
# Epoch [1/3], Step [34/63], Loss: 0.8612, Perplexity: 2.3660
# Sampled caption length: 14
# Epoch [1/3], Step [35/63], Loss: 0.8433, Perplexity: 2.3240
# Sampled caption length: 13
# Epoch [1/3], Step [36/63], Loss: 0.8392, Perplexity: 2.3145
# Sampled caption length: 10
# Epoch [1/3], Step [37/63], Loss: 0.8470, Perplexity: 2.3326
# Sampled caption length: 18
# Epoch [1/3], Step [38/63], Loss: 0.8178, Perplexity: 2.2654
# Sampled caption length: 14
# Epoch [1/3], Step [39/63], Loss: 0.8164, Perplexity: 2.2624
# Sampled caption length: 13
# Epoch [1/3], Step [40/63], Loss: 0.8134, Perplexity: 2.2555
# Sampled caption length: 13
# Epoch [1/3], Step [41/63], Loss: 0.8075, Perplexity: 2.2424
# Sampled caption length: 11
# Epoch [1/3], Step [42/63], Loss: 0.8094, Perplexity: 2.2465
# Sampled caption length: 12
# Epoch [1/3], Step [43/63], Loss: 0.8049, Perplexity: 2.2365
# Sampled caption length: 12
# Epoch [1/3], Step [44/63], Loss: 0.7930, Perplexity: 2.2101
# Sampled caption length: 11
# Epoch [1/3], Step [45/63], Loss: 0.7886, Perplexity: 2.2003
# Sampled caption length: 10
# Epoch [1/3], Step [46/63], Loss: 0.7934, Perplexity: 2.2110
# Sampled caption length: 12
# Epoch [1/3], Step [47/63], Loss: 0.7779, Perplexity: 2.1769
# Sampled caption length: 12
# Epoch [1/3], Step [48/63], Loss: 0.7703, Perplexity: 2.1605
# Sampled caption length: 13
# Epoch [1/3], Step [49/63], Loss: 0.7616, Perplexity: 2.1416
# Sampled caption length: 15
# Epoch [1/3], Step [50/63], Loss: 0.7392, Perplexity: 2.0943
# Sampled caption length: 13
# Epoch [1/3], Step [51/63], Loss: 0.7437, Perplexity: 2.1037
# Sampled caption length: 11
# Epoch [1/3], Step [52/63], Loss: 0.7574, Perplexity: 2.1328
# Sampled caption length: 12
# Epoch [1/3], Step [53/63], Loss: 0.7415, Perplexity: 2.0992
# Sampled caption length: 13
# Epoch [1/3], Step [54/63], Loss: 0.7295, Perplexity: 2.0740
# Sampled caption length: 11
# Epoch [1/3], Step [55/63], Loss: 0.7357, Perplexity: 2.0870
# Sampled caption length: 11
# Epoch [1/3], Step [56/63], Loss: 0.7323, Perplexity: 2.0798
# Sampled caption length: 13
# Epoch [1/3], Step [57/63], Loss: 0.7152, Perplexity: 2.0446
# Sampled caption length: 13
# Epoch [1/3], Step [58/63], Loss: 0.7050, Perplexity: 2.0238
# Sampled caption length: 12
# Epoch [1/3], Step [59/63], Loss: 0.7052, Perplexity: 2.0242
# Sampled caption length: 13
# Epoch [1/3], Step [60/63], Loss: 0.7022, Perplexity: 2.0182
# Sampled caption length: 16
# Epoch [1/3], Step [61/63], Loss: 0.6698, Perplexity: 1.9539
# Sampled caption length: 12
# Epoch [1/3], Step [62/63], Loss: 0.6886, Perplexity: 1.9909
# Sampled caption length: 11
# Epoch [1/3], Step [63/63], Loss: 0.6980, Perplexity: 2.0096
# Sampled caption length: 13
# Epoch [2/3], Step [1/63], Loss: 0.6709, Perplexity: 1.9560
# Sampled caption length: 11
# Epoch [2/3], Step [2/63], Loss: 0.6839, Perplexity: 1.9815
# Sampled caption length: 11
# Epoch [2/3], Step [3/63], Loss: 0.6752, Perplexity: 1.9645
# Sampled caption length: 13
# Epoch [2/3], Step [4/63], Loss: 0.6592, Perplexity: 1.9332
# Sampled caption length: 12
# Epoch [2/3], Step [5/63], Loss: 0.6651, Perplexity: 1.9446
# Sampled caption length: 16
# Epoch [2/3], Step [6/63], Loss: 0.6352, Perplexity: 1.8874
# Sampled caption length: 12
# Epoch [2/3], Step [7/63], Loss: 0.6520, Perplexity: 1.9195
# Sampled caption length: 15
# Epoch [2/3], Step [8/63], Loss: 0.6229, Perplexity: 1.8643
# Sampled caption length: 12
# Epoch [2/3], Step [9/63], Loss: 0.6426, Perplexity: 1.9015
# Sampled caption length: 13
# Epoch [2/3], Step [10/63], Loss: 0.6246, Perplexity: 1.8674
# Sampled caption length: 11
# Epoch [2/3], Step [11/63], Loss: 0.6357, Perplexity: 1.8883
# Sampled caption length: 12
# Epoch [2/3], Step [12/63], Loss: 0.6337, Perplexity: 1.8845
# Sampled caption length: 11
# Epoch [2/3], Step [13/63], Loss: 0.6369, Perplexity: 1.8905
# Sampled caption length: 11
# Epoch [2/3], Step [14/63], Loss: 0.6302, Perplexity: 1.8780
# Sampled caption length: 14
# Epoch [2/3], Step [15/63], Loss: 0.5977, Perplexity: 1.8180
# Sampled caption length: 16
# Epoch [2/3], Step [16/63], Loss: 0.5757, Perplexity: 1.7783
# Sampled caption length: 11
# Epoch [2/3], Step [17/63], Loss: 0.6253, Perplexity: 1.8688
# Sampled caption length: 13
# Epoch [2/3], Step [18/63], Loss: 0.5926, Perplexity: 1.8088
# Sampled caption length: 12
# Epoch [2/3], Step [19/63], Loss: 0.5969, Perplexity: 1.8165
# Sampled caption length: 15
# Epoch [2/3], Step [20/63], Loss: 0.5660, Perplexity: 1.7612
# Sampled caption length: 14
# Epoch [2/3], Step [21/63], Loss: 0.5713, Perplexity: 1.7706
# Sampled caption length: 12
# Epoch [2/3], Step [22/63], Loss: 0.5898, Perplexity: 1.8037
# Sampled caption length: 17
# Epoch [2/3], Step [23/63], Loss: 0.5351, Perplexity: 1.7076
# Sampled caption length: 14
# Epoch [2/3], Step [24/63], Loss: 0.5523, Perplexity: 1.7373
# Sampled caption length: 14
# Epoch [2/3], Step [25/63], Loss: 0.5592, Perplexity: 1.7493
# Sampled caption length: 15
# Epoch [2/3], Step [26/63], Loss: 0.5414, Perplexity: 1.7184
# Sampled caption length: 16
# Epoch [2/3], Step [27/63], Loss: 0.5312, Perplexity: 1.7010
# Sampled caption length: 13
# Epoch [2/3], Step [28/63], Loss: 0.5446, Perplexity: 1.7240
# Sampled caption length: 11
# Epoch [2/3], Step [29/63], Loss: 0.5668, Perplexity: 1.7626
# Sampled caption length: 11
# Epoch [2/3], Step [30/63], Loss: 0.5691, Perplexity: 1.7667
# Sampled caption length: 13
# Epoch [2/3], Step [31/63], Loss: 0.5468, Perplexity: 1.7276
# Sampled caption length: 16
# Epoch [2/3], Step [32/63], Loss: 0.5069, Perplexity: 1.6602
# Sampled caption length: 18
# Epoch [2/3], Step [33/63], Loss: 0.4899, Perplexity: 1.6321
# Sampled caption length: 11
# Epoch [2/3], Step [34/63], Loss: 0.5633, Perplexity: 1.7564
# Sampled caption length: 15
# Epoch [2/3], Step [35/63], Loss: 0.5075, Perplexity: 1.6612
# Sampled caption length: 14
# Epoch [2/3], Step [36/63], Loss: 0.5107, Perplexity: 1.6664
# Sampled caption length: 14
# Epoch [2/3], Step [37/63], Loss: 0.5103, Perplexity: 1.6657
# Sampled caption length: 14
# Epoch [2/3], Step [38/63], Loss: 0.5068, Perplexity: 1.6600
# Sampled caption length: 16
# Epoch [2/3], Step [39/63], Loss: 0.4897, Perplexity: 1.6319
# Sampled caption length: 14
# Epoch [2/3], Step [40/63], Loss: 0.4986, Perplexity: 1.6463
# Sampled caption length: 11
# Epoch [2/3], Step [41/63], Loss: 0.5244, Perplexity: 1.6895
# Sampled caption length: 12
# Epoch [2/3], Step [42/63], Loss: 0.5186, Perplexity: 1.6797
# Sampled caption length: 11
# Epoch [2/3], Step [43/63], Loss: 0.5290, Perplexity: 1.6973
# Sampled caption length: 13
# Epoch [2/3], Step [44/63], Loss: 0.4967, Perplexity: 1.6433
# Sampled caption length: 15
# Epoch [2/3], Step [45/63], Loss: 0.4745, Perplexity: 1.6072
# Sampled caption length: 12
# Epoch [2/3], Step [46/63], Loss: 0.5133, Perplexity: 1.6708
# Sampled caption length: 15
# Epoch [2/3], Step [47/63], Loss: 0.4683, Perplexity: 1.5973
# Sampled caption length: 13
# Epoch [2/3], Step [48/63], Loss: 0.4824, Perplexity: 1.6200
# Sampled caption length: 11
# Epoch [2/3], Step [49/63], Loss: 0.5188, Perplexity: 1.6800
# Sampled caption length: 14
# Epoch [2/3], Step [50/63], Loss: 0.4745, Perplexity: 1.6073
# Sampled caption length: 12
# Epoch [2/3], Step [51/63], Loss: 0.4900, Perplexity: 1.6323
# Sampled caption length: 12
# Epoch [2/3], Step [52/63], Loss: 0.4843, Perplexity: 1.6231
# Sampled caption length: 12
# Epoch [2/3], Step [53/63], Loss: 0.4852, Perplexity: 1.6245
# Sampled caption length: 14
# Epoch [2/3], Step [54/63], Loss: 0.4511, Perplexity: 1.5700
# Sampled caption length: 18
# Epoch [2/3], Step [55/63], Loss: 0.4201, Perplexity: 1.5221
# Sampled caption length: 15
# Epoch [2/3], Step [56/63], Loss: 0.4425, Perplexity: 1.5566
# Sampled caption length: 15
# Epoch [2/3], Step [57/63], Loss: 0.4428, Perplexity: 1.5571
# Sampled caption length: 11
# Epoch [2/3], Step [58/63], Loss: 0.4972, Perplexity: 1.6441
# Sampled caption length: 15
# Epoch [2/3], Step [59/63], Loss: 0.4321, Perplexity: 1.5405
# Sampled caption length: 12
# Epoch [2/3], Step [60/63], Loss: 0.4677, Perplexity: 1.5963
# Sampled caption length: 19
# Epoch [2/3], Step [61/63], Loss: 0.3973, Perplexity: 1.4878
# Sampled caption length: 11
# Epoch [2/3], Step [62/63], Loss: 0.4859, Perplexity: 1.6256
# Sampled caption length: 13
# Epoch [2/3], Step [63/63], Loss: 0.4477, Perplexity: 1.5647
# Sampled caption length: 13
# Epoch [3/3], Step [1/63], Loss: 0.4480, Perplexity: 1.5652
# Sampled caption length: 12
# Epoch [3/3], Step [2/63], Loss: 0.4609, Perplexity: 1.5855
# Sampled caption length: 18
# Epoch [3/3], Step [3/63], Loss: 0.3938, Perplexity: 1.4827
# Sampled caption length: 12
# Epoch [3/3], Step [4/63], Loss: 0.4634, Perplexity: 1.5894
# Sampled caption length: 10
# Epoch [3/3], Step [5/63], Loss: 0.5096, Perplexity: 1.6646
# Sampled caption length: 14
# Epoch [3/3], Step [6/63], Loss: 0.4207, Perplexity: 1.5230
# Sampled caption length: 13
# Epoch [3/3], Step [7/63], Loss: 0.4295, Perplexity: 1.5365
# Sampled caption length: 16
# Epoch [3/3], Step [8/63], Loss: 0.4023, Perplexity: 1.4953
# Sampled caption length: 15
# Epoch [3/3], Step [9/63], Loss: 0.4044, Perplexity: 1.4983
# Sampled caption length: 12
# Epoch [3/3], Step [10/63], Loss: 0.4541, Perplexity: 1.5747
# Sampled caption length: 14
# Epoch [3/3], Step [11/63], Loss: 0.4209, Perplexity: 1.5234
# Sampled caption length: 11
# Epoch [3/3], Step [12/63], Loss: 0.4723, Perplexity: 1.6038
# Sampled caption length: 13
# Epoch [3/3], Step [13/63], Loss: 0.4309, Perplexity: 1.5386
# Sampled caption length: 16
# Epoch [3/3], Step [14/63], Loss: 0.3945, Perplexity: 1.4836
# Sampled caption length: 12
# Epoch [3/3], Step [15/63], Loss: 0.4442, Perplexity: 1.5593
# Sampled caption length: 16
# Epoch [3/3], Step [16/63], Loss: 0.3924, Perplexity: 1.4805
# Sampled caption length: 14
# Epoch [3/3], Step [17/63], Loss: 0.4080, Perplexity: 1.5037
# Sampled caption length: 12
# Epoch [3/3], Step [18/63], Loss: 0.4353, Perplexity: 1.5454
# Sampled caption length: 14
# Epoch [3/3], Step [19/63], Loss: 0.4013, Perplexity: 1.4937
# Sampled caption length: 13
# Epoch [3/3], Step [20/63], Loss: 0.4258, Perplexity: 1.5307
# Sampled caption length: 11
# Epoch [3/3], Step [21/63], Loss: 0.4513, Perplexity: 1.5704
# Sampled caption length: 13
# Epoch [3/3], Step [22/63], Loss: 0.4147, Perplexity: 1.5139
# Sampled caption length: 11
# Epoch [3/3], Step [23/63], Loss: 0.4613, Perplexity: 1.5861
# Sampled caption length: 11
# Epoch [3/3], Step [24/63], Loss: 0.4544, Perplexity: 1.5753
# Sampled caption length: 11
# Epoch [3/3], Step [25/63], Loss: 0.4586, Perplexity: 1.5819
# Sampled caption length: 11
# Epoch [3/3], Step [26/63], Loss: 0.4456, Perplexity: 1.5614
# Sampled caption length: 19
# Epoch [3/3], Step [27/63], Loss: 0.3470, Perplexity: 1.4149
# Sampled caption length: 18
# Epoch [3/3], Step [28/63], Loss: 0.3489, Perplexity: 1.4175
# Sampled caption length: 11
# Epoch [3/3], Step [29/63], Loss: 0.4425, Perplexity: 1.5567
# Sampled caption length: 15
# Epoch [3/3], Step [30/63], Loss: 0.3844, Perplexity: 1.4687
# Sampled caption length: 16
# Epoch [3/3], Step [31/63], Loss: 0.3679, Perplexity: 1.4447
# Sampled caption length: 11
# Epoch [3/3], Step [32/63], Loss: 0.4498, Perplexity: 1.5680
# Sampled caption length: 11
# Epoch [3/3], Step [33/63], Loss: 0.4336, Perplexity: 1.5428
# Sampled caption length: 11
# Epoch [3/3], Step [34/63], Loss: 0.4404, Perplexity: 1.5533
# Sampled caption length: 14
# Epoch [3/3], Step [35/63], Loss: 0.3871, Perplexity: 1.4728
# Sampled caption length: 15
# Epoch [3/3], Step [36/63], Loss: 0.3799, Perplexity: 1.4621
# Sampled caption length: 13
# Epoch [3/3], Step [37/63], Loss: 0.4028, Perplexity: 1.4960
# Sampled caption length: 14
# Epoch [3/3], Step [38/63], Loss: 0.3901, Perplexity: 1.4772
# Sampled caption length: 11
# Epoch [3/3], Step [39/63], Loss: 0.4299, Perplexity: 1.5371
# Sampled caption length: 17
# Epoch [3/3], Step [40/63], Loss: 0.3545, Perplexity: 1.4255
# Sampled caption length: 18
# Epoch [3/3], Step [41/63], Loss: 0.3345, Perplexity: 1.3973
# Sampled caption length: 11
# Epoch [3/3], Step [42/63], Loss: 0.4275, Perplexity: 1.5334
# Sampled caption length: 14
# Epoch [3/3], Step [43/63], Loss: 0.3804, Perplexity: 1.4629
# Sampled caption length: 16
# Epoch [3/3], Step [44/63], Loss: 0.3636, Perplexity: 1.4385
# Sampled caption length: 14
# Epoch [3/3], Step [45/63], Loss: 0.3795, Perplexity: 1.4615
# Sampled caption length: 12
# Epoch [3/3], Step [46/63], Loss: 0.4160, Perplexity: 1.5158
# Sampled caption length: 11
# Epoch [3/3], Step [47/63], Loss: 0.4325, Perplexity: 1.5410
# Sampled caption length: 11
# Epoch [3/3], Step [48/63], Loss: 0.4204, Perplexity: 1.5226
# Sampled caption length: 12
# Epoch [3/3], Step [49/63], Loss: 0.4105, Perplexity: 1.5076
# Sampled caption length: 14
# Epoch [3/3], Step [50/63], Loss: 0.3694, Perplexity: 1.4469
# Sampled caption length: 11
# Epoch [3/3], Step [51/63], Loss: 0.4214, Perplexity: 1.5242
# Sampled caption length: 14
# Epoch [3/3], Step [52/63], Loss: 0.3645, Perplexity: 1.4398
# Sampled caption length: 11
# Epoch [3/3], Step [53/63], Loss: 0.4194, Perplexity: 1.5211
# Sampled caption length: 14
# Epoch [3/3], Step [54/63], Loss: 0.3727, Perplexity: 1.4516
# Sampled caption length: 11
# Epoch [3/3], Step [55/63], Loss: 0.4190, Perplexity: 1.5204
# Sampled caption length: 13
# Epoch [3/3], Step [56/63], Loss: 0.3805, Perplexity: 1.4631
# Sampled caption length: 13
# Epoch [3/3], Step [57/63], Loss: 0.3795, Perplexity: 1.4616
# Sampled caption length: 14
# Epoch [3/3], Step [58/63], Loss: 0.3663, Perplexity: 1.4424
# Sampled caption length: 19
# Epoch [3/3], Step [59/63], Loss: 0.3071, Perplexity: 1.3595
# Sampled caption length: 14
# Epoch [3/3], Step [60/63], Loss: 0.3696, Perplexity: 1.4472
# Sampled caption length: 11
# Epoch [3/3], Step [61/63], Loss: 0.4069, Perplexity: 1.5021
# Sampled caption length: 14
# Epoch [3/3], Step [62/63], Loss: 0.3707, Perplexity: 1.4487
# Sampled caption length: 12
# Epoch [3/3], Step [63/63], Loss: 0.3993, Perplexity: 1.4907

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
